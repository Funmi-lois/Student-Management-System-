# %% [markdown]
# <a href="https://colab.research.google.com/github/Funmi-lois/Student-Management-System-/blob/main/First_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world" )
# Out:
# hello world

# %% [markdown]
# This is heading

# %% [markdown]
# #This is heading

# %% [markdown]
# *markdown*

# %% [markdown]
# ##This is heading

# %% [markdown]
# **Heading**

# %% [markdown]
# - sit
# - fit

# %% [markdown]
# The Zen of Python

# %%
#import this
