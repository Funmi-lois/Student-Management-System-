# %% [markdown]
# <a href="https://colab.research.google.com/github/Funmi-lois/Student-Management-System-/blob/main/Copy_of_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# this is a markdown cell

# %% [markdown]
# # This is a heading
# ## This is another heading
#
# this is a normal text
#
# **bold**
#
# *italic*
#
# - list1
# - list2
